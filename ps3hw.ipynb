# %% [markdown]
# Name: Alex Semler

# %% [markdown]
# ## Problem Set 3 (Homework): Interacting with the Alpha Vantage API using Python libraries

# %% [markdown]
# Complete each step of boths parts of the notebook. The first part calls the Alpha Vantage API using the HTTP request library. The second part uses the Python Alpha Vantage library. Refer to Part 1 and Part 2 notebooks for code examples and any documentation.
#
# Documentation links:
# <br />Alpha Vantage: https://www.alphavantage.co/documentation/
# <br />Alpha Vantage Python library: https://alpha-vantage.readthedocs.io/en/latest/#
# <br />Pandas DataFrame: https://pandas.pydata.org/pandas-docs/stable/reference/frame.html

# %% [markdown]
# #### Part 1: Alpha Vantage HTTP (RESTful) API call

# %% [markdown]
# (1) Import the "requests" library:
# (1 point)

# %%
import requests

# %% [markdown]
# (2) Assign your Alpha Vantage API key to a variable: (1 point)

# %%
api_key = "P9Z8WUCN2O1MLR2A"

# %% [markdown]
# (3) Assign a stock ticker symbol to a variable: (1 point)

# %%
ticker = "AAPL"

# %% [markdown]
# (4) Make an API call using the Alpha Vantage HTTP API: (5 points)
# * Compose a URL string and assign it to a variable called link
# * Format the URL with the above variables used for your API key and stock ticker symbol
# * Get daily stock data for the last 100 obervations
# * Retrieve the data as type CSV
# * Refer to the documentation: https://www.alphavantage.co/documentation/

# %%
link = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={ticker}&outputsize=compact&apikey={api_key}&datatype=csv"
print(link)
# Out:
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AAPL&outputsize=compact&apikey=P9Z8WUCN2O1MLR2A&datatype=csv

# %% [markdown]
# (5) Print the output from the HTTP API call: (2 points)
# * It should print as text in CSV format

# %%
aapl = requests.get(link)
print(aapl.text)
# Out:
# timestamp,open,high,low,close,volume
# 2019-09-30,220.9000,224.5700,220.7900,223.9700,23060621
# 2019-09-27,220.5400,220.9600,217.2800,218.8200,25352000
# 2019-09-26,220.0000,220.9400,218.8300,219.8900,18833500
# 2019-09-25,218.5500,221.5000,217.1400,221.0300,21903400
# 2019-09-24,221.0300,222.4900,217.1900,217.6800,31190800
# 2019-09-23,218.9500,219.8400,217.6500,218.7200,19165500
# 2019-09-20,221.3800,222.5600,217.4700,217.7300,55413100
# 2019-09-19,222.0100,223.7600,220.3700,220.9600,22060600
# 2019-09-18,221.0600,222.8500,219.4400,222.7700,25340000
# 2019-09-17,219.9600,220.8200,219.1200,220.7000,18318700
# 2019-09-16,217.7300,220.1300,217.5600,219.9000,21158100
# 2019-09-13,220.0000,220.7900,217.0200,218.7500,39763300
# 2019-09-12,224.8000,226.4200,222.8600,223.0900,32226700
# 2019-09-11,218.0700,223.7100,217.7300,223.5900,44289600
# 2019-09-10,213.8600,216.7800,211.7100,216.7000,31777900
# 2019-09-09,214.8400,216.4400,211.0700,214.1700,27309400
# 2019-09-06,214.0500,214.4200,212.5100,213.2600,19362300
# 2019-09-05,212.0000,213.9700,211.5100,213.2800,23913700
# 2019-09-04,208.3900,209.4800,207.3200,209.1900,19188100
# 2019-09-03,206.4300,206.9800,204.2200,205.7000,20023000
# 2019-08-30,210.1600,210.4500,207.2000,208.7400,21143400
# 2019-08-29,208.5000,209.3200,206.6600,209.0100,20990500
# 2019-08-28,204.1000,205.7200,203.3200,205.5300,15938800
# 2019-08-27,207.8600,208.5500,203.5300,204.1600,25873300
# 2019-08-26,205.8600,207.1900,205.0600,206.4900,26043600
# 2019-08-23,209.4300,212.0500,201.0000,202.6400,46818000
# 2019-08-22,213.1900,214.4400,210.7500,212.4600,22253700
# 2019-06-10,191.8100,195.3700,191.6200,192.5800,26220900
# 2019-06-07,186.5100,191.9200,185.7700,190.1500,30684400
# 2019-06-06,183.0800,185.4700,182.1490,185.2200,22526300
# 2019-06-05,184.2800,184.9900,181.1400,182.5400,29773400
# 2019-06-04,175.4400,179.8300,174.5200,179.6400,30968000
# 2019-06-03,175.6000,177.9200,170.2700,173.3000,40396100
# 2019-05-31,176.2386,177.9900,174.9900,175.0700,27043600
# 2019-05-30,177.9500,179.2300,176.6700,178.3000,21218400
# 2019-05-29,176.4200,179.3500,176.0000,177.3800,28481200
# 2019-05-28,178.9200,180.5823,177.9100,178.2300,27948200
# 2019-05-24,180.1912,182.1400,178.6200,178.9700,23714700
# 2019-05-23,179.8000,180.5400,177.8100,179.6600,36529700
# 2019-05-22,184.6600,185.7100,182.5500,182.7800,29748600
# 2019-05-21,185.2200,188.0000,184.7066,186.6000,28364800
# 2019-05-20,183.5200,184.3490,180.2840,183.0900,38612300
# 2019-05-17,186.9300,190.9000,186.7600,189.0000,32879100
# 2019-05-16,189.9100,192.4690,188.8400,190.0800,33031400
# 2019-05-15,186.2700,191.7500,186.0200,190.9200,26544700
# 2019-05-14,186.4100,189.7000,185.4100,188.6600,36529700
# 2019-05-13,187.7167,189.4800,182.8500,185.7200,57430600
# 2019-05-10,197.4190,198.8440,192.7700,197.1800,41208700
# 2019-05-09,200.3916,201.6800,196.6600,200.7200,34908600

# %% [markdown]
# #### Part 2: API call using alpha_vantage Python library
# Refer to the docs: https://alpha-vantage.readthedocs.io/en/latest/

# %% [markdown]
# (1) Import the necessary items (2 lines): (2 points)

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# (2) Create an instance of the TimeSeries class: (2 points)
# * Use the API key variable assigned in Part 1
# * Import the data as a pandas dataframe

# %%
ts = TimeSeries(key=api_key,output_format='pandas')

# %% [markdown]
# (3) Retrieve daily stock price data by calling the API with the appropriate "get" method: (5 point)
# * Use the ticket symbol variable you used in Part 1 as an argument in the get method
# * Get the last 100 obervations
# * Store the time series data and the meta data into two separate variables on the same line
# * Refer to the docs: https://alpha-vantage.readthedocs.io/en/latest/genindex.html

# %%
data, meta_data = ts.get_daily(symbol=ticker,outputsize="compact")

# %% [markdown]
# (4) Print the dataframe (1 point)

# %%
print(data)
# Out:
#              1. open   2. high    3. low  4. close   5. volume
# date
# 2019-05-09  200.3916  201.6800  196.6600    200.72  34908600.0
# 2019-05-10  197.4190  198.8440  192.7700    197.18  41208700.0
# 2019-05-13  187.7167  189.4800  182.8500    185.72  57430600.0
# 2019-05-14  186.4100  189.7000  185.4100    188.66  36529700.0
# 2019-05-15  186.2700  191.7500  186.0200    190.92  26544700.0
# 2019-05-16  189.9100  192.4690  188.8400    190.08  33031400.0
# 2019-05-17  186.9300  190.9000  186.7600    189.00  32879100.0
# 2019-05-20  183.5200  184.3490  180.2840    183.09  38612300.0
# 2019-05-21  185.2200  188.0000  184.7066    186.60  28364800.0
# 2019-05-22  184.6600  185.7100  182.5500    182.78  29748600.0
# 2019-05-23  179.8000  180.5400  177.8100    179.66  36529700.0
# 2019-05-24  180.1912  182.1400  178.6200    178.97  23714700.0
# 2019-05-28  178.9200  180.5823  177.9100    178.23  27948200.0
# 2019-05-29  176.4200  179.3500  176.0000    177.38  28481200.0
# 2019-05-30  177.9500  179.2300  176.6700    178.30  21218400.0
# 2019-05-31  176.2386  177.9900  174.9900    175.07  27043600.0
# 2019-06-03  175.6000  177.9200  170.2700    173.30  40396100.0
# 2019-06-04  175.4400  179.8300  174.5200    179.64  30968000.0
# 2019-06-05  184.2800  184.9900  181.1400    182.54  29773400.0
# 2019-06-06  183.0800  185.4700  182.1490    185.22  22526300.0
# 2019-06-07  186.5100  191.9200  185.7700    190.15  30684400.0
# 2019-06-10  191.8100  195.3700  191.6200    192.58  26220900.0
# 2019-06-11  194.8600  196.0000  193.6000    194.81  26932900.0
# 2019-06-12  193.9491  195.9700  193.3850    194.19  18253200.0
# 2019-06-13  194.7000  196.7900  193.6000    194.15  21674600.0
# 2019-06-14  191.5384  193.5860  190.3000    192.74  18761500.0
# 2019-06-17  192.9000  194.9553  192.1700    193.89  14669100.0
# 2019-06-18  196.0500  200.2900  195.2100    198.45  26551000.0
# 2019-06-19  199.6800  199.8800  197.3057    197.87  21124200.0
# 2019-06-20  200.3543  200.6100  198.0300    199.46  21514000.0
# ...              ...       ...       ...       ...         ...
# 2019-08-19  210.6200  212.7300  210.0300    210.35  24413600.0
# 2019-08-20  210.8800  213.3500  210.3200    210.36  26884300.0
# 2019-08-21  212.9900  213.6500  211.6000    212.64  21535400.0
# 2019-08-22  213.1900  214.4400  210.7500    212.46  22253700.0
# 2019-08-23  209.4300  212.0500  201.0000    202.64  46818000.0
# 2019-08-26  205.8600  207.1900  205.0600    206.49  26043600.0
# 2019-08-27  207.8600  208.5500  203.5300    204.16  25873300.0
# 2019-08-28  204.1000  205.7200  203.3200    205.53  15938800.0
# 2019-08-29  208.5000  209.3200  206.6600    209.01  20990500.0
# 2019-08-30  210.1600  210.4500  207.2000    208.74  21143400.0
# 2019-09-03  206.4300  206.9800  204.2200    205.70  20023000.0
# 2019-09-04  208.3900  209.4800  207.3200    209.19  19188100.0
# 2019-09-05  212.0000  213.9700  211.5100    213.28  23913700.0
# 2019-09-06  214.0500  214.4200  212.5100    213.26  19362300.0
# 2019-09-09  214.8400  216.4400  211.0700    214.17  27309400.0
# 2019-09-10  213.8600  216.7800  211.7100    216.70  31777900.0
# 2019-09-11  218.0700  223.7100  217.7300    223.59  44289600.0
# 2019-09-12  224.8000  226.4200  222.8600    223.09  32226700.0
# 2019-09-13  220.0000  220.7900  217.0200    218.75  39763300.0
# 2019-09-16  217.7300  220.1300  217.5600    219.90  21158100.0
# 2019-09-17  219.9600  220.8200  219.1200    220.70  18318700.0
# 2019-09-18  221.0600  222.8500  219.4400    222.77  25340000.0
# 2019-09-19  222.0100  223.7600  220.3700    220.96  22060600.0
# 2019-09-20  221.3800  222.5600  217.4700    217.73  55413100.0
# 2019-09-23  218.9500  219.8400  217.6500    218.72  19165500.0
# 2019-09-24  221.0300  222.4900  217.1900    217.68  31190800.0
# 2019-09-25  218.5500  221.5000  217.1400    221.03  21903400.0
# 2019-09-26  220.0000  220.9400  218.8300    219.89  18833500.0
# 2019-09-27  220.5400  220.9600  217.2800    218.82  25352000.0
# 2019-09-30  220.9000  224.5700  220.7900    223.97  23060621.0
#
# [100 rows x 5 columns]

# %% [markdown]
# (BONUS POINT) Print just the highest closing price of the last 100 obervations:
# * Refer to the pandas docs: https://pandas.pydata.org/pandas-docs/stable/

# %%
print(data.max())
# Out:
# 1. open           224.80
# 2. high           226.42
# 3. low            222.86
# 4. close          223.97
# 5. volume    69281400.00
# dtype: float64
